# %%
import pandas as pd

url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"

iris = pd.read_csv(url)

iris.head()

"""
1. **Sepal Length**: De lengte van de kelkbladen in centimeters.
2. **Sepal Width**: De breedte van de kelkbladen in centimeters.
3. **Petal Length**: De lengte van de bloemblaadjes in centimeters.
4. **Petal Width**: De breedte van de bloemblaadjes in centimeters.

"""
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.054000      3.758667     1.198667     NaN
# std         0.828066     0.433594      1.764420     0.763161     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
iris['sepal_length'].head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
iris.loc[12:19, ['sepal_length', 'sepal_width']]
# Out:
#     sepal_length  sepal_width
# 12           4.8          3.0
# 13           4.3          3.0
# 14           5.8          4.0
# 15           5.7          4.4
# 16           5.4          3.9
# 17           5.1          3.5
# 18           5.7          3.8
# 19           5.1          3.8

# %%
iris[iris['species'] == 'setosa'].iloc[30:40]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 30           4.8          3.1           1.6          0.2  setosa
# 31           5.4          3.4           1.5          0.4  setosa
# 32           5.2          4.1           1.5          0.1  setosa
# 33           5.5          4.2           1.4          0.2  setosa
# 34           4.9          3.1           1.5          0.1  setosa
# 35           5.0          3.2           1.2          0.2  setosa
# 36           5.5          3.5           1.3          0.2  setosa
# 37           4.9          3.1           1.5          0.1  setosa
# 38           4.4          3.0           1.3          0.2  setosa
# 39           5.1          3.4           1.5          0.2  setosa

# %%
iris.sort_values(by='sepal_length').head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 13           4.3          3.0           1.1          0.1  setosa
# 42           4.4          3.2           1.3          0.2  setosa
# 38           4.4          3.0           1.3          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 41           4.5          2.3           1.3          0.3  setosa

# %%
iris[iris['species'] == 'setosa'].sort_values(by='petal_width').iloc[30:32]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 11           4.8          3.4           1.6          0.2  setosa
# 14           5.8          4.0           1.2          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris[(iris['species'] == 'setosa') & (iris['petal_width'] > 0) & (iris['sepal_length'] > 5.4)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 33           5.5          4.2           1.4          0.2  setosa
# 36           5.5          3.5           1.3          0.2  setosa

# %%
iris_group_1 = iris[(iris['petal_width'] > 0.1) & (iris['sepal_length'] > 3)].groupby('species').apply(lambda x: x)
# Out:
# C:\Users\Stichting GeoFort\AppData\Local\Temp\ipykernel_14428\2117231495.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   iris_group_1 = iris[(iris['petal_width'] > 0.1) & (iris['sepal_length'] > 3)].groupby('species').apply(lambda x: x)

# %%
iris_group_1.reset_index(drop=True, inplace=True)

# %%
iris_group_1[iris_group_1['species'] == 'setosa'].iloc[10:20]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 10           4.8          3.4           1.6          0.2  setosa
# 11           5.8          4.0           1.2          0.2  setosa
# 12           5.7          4.4           1.5          0.4  setosa
# 13           5.4          3.9           1.3          0.4  setosa
# 14           5.1          3.5           1.4          0.3  setosa
# 15           5.7          3.8           1.7          0.3  setosa
# 16           5.1          3.8           1.5          0.3  setosa
# 17           5.4          3.4           1.7          0.2  setosa
# 18           5.1          3.7           1.5          0.4  setosa
# 19           4.6          3.6           1.0          0.2  setosa

# %%
#oefening met ontbrekende waarden

iris.iloc[0,1] # eerste rij, tweede kolom
# Out:
# 3.5

# %%
iris.columns[1]
# Out:
# 'sepal_width'

# %%
iris.iloc[0]['species']
# Out:
# 'setosa'

# %%
iris.loc[[0], ['species', iris.columns[1]]]
# Out:
#   species  sepal_width
# 0  setosa          3.5

# %%
iris.loc[[0], ['species', iris.columns[1], iris.columns[2]]]
# Out:
#   species  sepal_width  petal_length
# 0  setosa          3.5           1.4

# %%
iris.iloc[0,1] = None

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     1
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris['sepal_width'].fillna(iris['sepal_width'].mean(), inplace=True)
# Out:
# C:\Users\Stichting GeoFort\AppData\Local\Temp\ipykernel_14428\2034228717.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   iris['sepal_width'].fillna(iris['sepal_width'].mean(), inplace=True)

# %%
iris.groupby('species').mean().head()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006      3.40902         1.464        0.244
# versicolor         5.936      2.77000         4.260        1.326
# virginica          6.588      2.97400         5.552        2.026

# %%
iris.groupby('species').agg(['mean', 'std'])
# Out:
#            sepal_length           sepal_width           petal_length  \
#                    mean       std        mean       std         mean
# species
# setosa            5.006  0.352490     3.40902  0.384329        1.464
# versicolor        5.936  0.516171     2.77000  0.313798        4.260
# virginica         6.588  0.635880     2.97400  0.322497        5.552
#
#                      petal_width
#                  std        mean       std
# species
# setosa      0.173511       0.244  0.107210
# versicolor  0.469911       1.326  0.197753
# virginica   0.551895       2.026  0.274650

# %%
iris_1 = iris.iloc[:75]
iris_2 = iris.iloc[75:]

iris_concat = pd.concat([iris_1, iris_2])

# %%
iris_concat.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1     3.051007           1.4          0.2  setosa
# 1           4.9     3.000000           1.4          0.2  setosa
# 2           4.7     3.200000           1.3          0.2  setosa
# 3           4.6     3.100000           1.5          0.2  setosa
# 4           5.0     3.600000           1.4          0.2  setosa

# %%
species_info = pd.DataFrame({ 'species': ['setosa', 'versicolor', 'virginica'], 'species_id': [1, 2, 3]})

species_info.head()
# Out:
#       species  species_id
# 0      setosa           1
# 1  versicolor           2
# 2   virginica           3

# %%
iris_merged = pd.merge(iris, species_info, on='species')

iris_merged.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1     3.051007           1.4          0.2  setosa           1
# 1           4.9     3.000000           1.4          0.2  setosa           1
# 2           4.7     3.200000           1.3          0.2  setosa           1
# 3           4.6     3.100000           1.5          0.2  setosa           1
# 4           5.0     3.600000           1.4          0.2  setosa           1

# %%
pivot_table_iris = iris.pivot_table(index='species', values=['sepal_length', 'petal_length'], aggfunc=['mean','min','max'])

pivot_table_iris.head()
# Out:
#                    mean                       min                       max  \
#            petal_length sepal_length petal_length sepal_length petal_length
# species
# setosa            1.464        5.006          1.0          4.3          1.9
# versicolor        4.260        5.936          3.0          4.9          5.1
# virginica         5.552        6.588          4.5          4.9          6.9
#
#
#            sepal_length
# species
# setosa              5.8
# versicolor          7.0
# virginica           7.9

# %%
cross_tab_iris = pd.crosstab(iris['species'], columns='count')

cross_tab_iris
# Out:
# col_0       count
# species
# setosa         50
# versicolor     50
# virginica      50

# %%
iris['lengte_categorie'] = iris['sepal_length'].apply(lambda x: 'Lang' if x > 5.8 else 'Kort')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1     3.051007           1.4          0.2  setosa
# 1           4.9     3.000000           1.4          0.2  setosa
# 2           4.7     3.200000           1.3          0.2  setosa
# 3           4.6     3.100000           1.5          0.2  setosa
# 4           5.0     3.600000           1.4          0.2  setosa
#
#   lengte_categorie
# 0             Kort
# 1             Kort
# 2             Kort
# 3             Kort
# 4             Kort

# %%
iris.groupby('species')['lengte_categorie'].value_counts().unstack()
# Out:
# lengte_categorie  Kort  Lang
# species
# setosa            50.0   NaN
# versicolor        24.0  26.0
# virginica          6.0  44.0

# %%
species_mapping = {'setosa': 'S', 'versicolor': 'V', 'virginica': 'VG'}

iris['species_code'] = iris['species'].map(species_mapping)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1     3.051007           1.4          0.2  setosa
# 1           4.9     3.000000           1.4          0.2  setosa
# 2           4.7     3.200000           1.3          0.2  setosa
# 3           4.6     3.100000           1.5          0.2  setosa
# 4           5.0     3.600000           1.4          0.2  setosa
#
#   lengte_categorie species_code
# 0             Kort            S
# 1             Kort            S
# 2             Kort            S
# 3             Kort            S
# 4             Kort            S

# %%
import matplotlib.pyplot as plt

kleuren = {'sepal_length': 'red', 'sepal_width': 'green', 'petal_length': 'blue', 'petal_width': 'purple'}
markers = {'setosa': 'o', 'versicolor': 's', 'virginica': '^'}

# Maak een figuur en as object aan
plt.figure(figsize=(10, 8))

for species, group in iris.groupby('species'):
    for feature in kleuren:
        plt.scatter(group[feature], group[feature],
                    color=kleuren[feature], alpha=0.5, label=f'{feature} ({species})', marker=markers[species])

# Verbeter de legenda
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))  # Verwijder duplicaten
plt.legend(by_label.values(), by_label.keys())

plt.title('Iris Dataset Kenmerken per Soort')
plt.xlabel('Waarde')
plt.ylabel('Waarde')
plt.grid(True)
plt.show()

# %%
kleuren = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
# Definieer markertypes voor elk kenmerk paar
markers = [('o', 'Sepal'), ('s', 'Petal')]

# Maak een figuur en as object aan
plt.figure(figsize=(10, 8))

for (marker, kenmerk_type) in markers:
    for species, group in iris.groupby('species'):
        if kenmerk_type == 'Sepal':
            plt.scatter(group['sepal_length'], group['sepal_width'], 
                        color=kleuren[species], alpha=0.5, label=f'{species} {kenmerk_type}', marker=marker)
        else:
            plt.scatter(group['petal_length'], group['petal_width'], 
                        color=kleuren[species], alpha=0.5, label=f'{species} {kenmerk_type}', marker=marker)

# Verbeter de legenda
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))  # Verwijder duplicaten
plt.legend(by_label.values(), by_label.keys(), title="Species & Kenmerk")

plt.title('Iris Dataset Kenmerken per Soort')
plt.xlabel('Length')
plt.ylabel('Width')
plt.grid(True)
plt.show()
